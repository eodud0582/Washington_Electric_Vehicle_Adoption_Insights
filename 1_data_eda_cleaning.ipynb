# %% [markdown]
# # Electric Vehicle in Washington State

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import pickle
# import missingno as msno

# %%
from IPython.display import display, HTML

def print_all(df): 
    with pd.option_context('display.max_rows',None):
        with pd.option_context('display.max_columns',None):
            with pd.option_context('display.float_format', '{:,.4f}'.format):
                with pd.option_context('display.float_format', '{:,.4f}'.format): # 셀 안의 내용 전체 출력
                    print(df.shape)
                    display(df)

def print_cols(df, n=5): 
    with pd.option_context('display.max_columns',None):
        with pd.option_context('display.float_format', '{:,.4f}'.format):
            print(df.shape)
            display(df[:n])

# %%
def get_heatmap(df, title=''):
    cmap = sns.diverging_palette(220, 10, as_cmap=True) # custom diverging colormap
    plt.figure(figsize=(8, 6))
    corr_matrix = df.corr(numeric_only=True)
    sns.heatmap(corr_matrix, annot=True, cmap=cmap, fmt='.2f', vmin=-1, vmax=1)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Electric Vehicle Population

# %%
# Electric Vehicle Population Data

ev = pd.read_csv('./data/Electric_Vehicle_Population_Data_20241003.csv'
                 , dtype={'Postal Code':'object'
                          , 'Legislative District':'object'
                          , 'DOL Vehicle ID':'object'
                          , '2020 Census Tract':'object'})
# lower case
ev.columns = ['_'.join(col.strip().lower().split()) for col in ev.columns]
# change column names
ev.rename(columns={'vin_(1-10)':'vin'
                    , 'electric_vehicle_type':'ev_type'
                    , 'clean_alternative_fuel_vehicle_(cafv)_eligibility':'cafv_eligibility'}
          , inplace=True)

# df = ev.copy() # copy
print_cols(ev, 2)
# Out:
# (205439, 17)
#           vin  county       city state postal_code  model_year    make  \
# 0  JTMAB3FV3P  Kitsap    Seabeck    WA       98380        2023  TOYOTA
# 1  1N4AZ1CP6J  Kitsap  Bremerton    WA       98312        2018  NISSAN
#
#         model                                 ev_type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        LEAF          Battery Electric Vehicle (BEV)
#
#                           cafv_eligibility  electric_range  base_msrp  \
# 0  Clean Alternative Fuel Vehicle Eligible         42.0000     0.0000
# 1  Clean Alternative Fuel Vehicle Eligible        151.0000     0.0000
#
#   legislative_district dol_vehicle_id                 vehicle_location  \
# 0                   35      240684006  POINT (-122.8728334 47.5798304)
# 1                   35      474183811  POINT (-122.6961203 47.5759584)
#
#          electric_utility 2020_census_tract
# 0  PUGET SOUND ENERGY INC       53035091301
# 1  PUGET SOUND ENERGY INC       53035080700

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205439 entries, 0 to 205438
# Data columns (total 17 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   vin                   205439 non-null  object
#  1   county                205436 non-null  object
#  2   city                  205436 non-null  object
#  3   state                 205439 non-null  object
#  4   postal_code           205436 non-null  object
#  5   model_year            205439 non-null  int64
#  6   make                  205439 non-null  object
#  7   model                 205438 non-null  object
#  8   ev_type               205439 non-null  object
#  9   cafv_eligibility      205439 non-null  object
#  10  electric_range        205431 non-null  float64
#  11  base_msrp             205431 non-null  float64
#  12  legislative_district  204997 non-null  object
#  13  dol_vehicle_id        205439 non-null  object
#  14  vehicle_location      205431 non-null  object
#  15  electric_utility      205436 non-null  object
#  16  2020_census_tract     205436 non-null  object
# dtypes: float64(2), int64(1), object(14)
# memory usage: 26.6+ MB

# %% [markdown]
# - size: 205,439 x 17

# %%
ev.describe(include='all').T
# Out:
#                          count  unique  \
# vin                     205439   12140
# county                  205436     205
# city                    205436     770
# state                   205439      45
# postal_code             205436     930
# model_year            205439.0     NaN
# make                    205439      42
# model                   205438     152
# ev_type                 205439       2
# cafv_eligibility        205439       3
# electric_range        205431.0     NaN
# base_msrp             205431.0     NaN
# legislative_district    204997      49
# dol_vehicle_id          205439  205439
# vehicle_location        205431     928
# electric_utility        205436      74
# 2020_census_tract       205436    2163
#
#                                                                     top  \
# vin                                                          7SAYGDEE6P
# county                                                             King
# city                                                            Seattle
# state                                                                WA
# postal_code                                                       98052
# model_year                                                          NaN
# make                                                              TESLA
# model                                                           MODEL Y
# ev_type                                  Battery Electric Vehicle (BEV)
# cafv_eligibility      Eligibility unknown as battery range has not b...
# electric_range                                                      NaN
# base_msrp                                                           NaN
# legislative_district                                                 41
# dol_vehicle_id                                                240684006
# vehicle_location                        POINT (-122.1207376 47.6705374)
# electric_utility          PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 2020_census_tract                                           53033028200
#
#                         freq         mean          std     min     25%  \
# vin                     1221          NaN          NaN     NaN     NaN
# county                105237          NaN          NaN     NaN     NaN
# city                   33328          NaN          NaN     NaN     NaN
# state                 204997          NaN          NaN     NaN     NaN
# postal_code             5203          NaN          NaN     NaN     NaN
# model_year               NaN  2020.960363     2.989059  1997.0  2019.0
# make                   90318          NaN          NaN     NaN     NaN
# model                  43437          NaN          NaN     NaN     NaN
# ev_type               161539          NaN          NaN     NaN     NaN
# cafv_eligibility      114172          NaN          NaN     NaN     NaN
# electric_range           NaN    52.164342    88.075859     0.0     0.0
# base_msrp                NaN   922.670532  7761.753602     0.0     0.0
# legislative_district   12994          NaN          NaN     NaN     NaN
# dol_vehicle_id             1          NaN          NaN     NaN     NaN
# vehicle_location        5203          NaN          NaN     NaN     NaN
# electric_utility       75156          NaN          NaN     NaN     NaN
# 2020_census_tract       2598          NaN          NaN     NaN     NaN
#
#                          50%     75%       max
# vin                      NaN     NaN       NaN
# county                   NaN     NaN       NaN
# city                     NaN     NaN       NaN
# state                    NaN     NaN       NaN
# postal_code              NaN     NaN       NaN
# model_year            2022.0  2023.0    2025.0
# make                     NaN     NaN       NaN
# model                    NaN     NaN       NaN
# ev_type                  NaN     NaN       NaN
# cafv_eligibility         NaN     NaN       NaN
# electric_range           0.0    48.0     337.0
# base_msrp                0.0     0.0  845000.0
# legislative_district     NaN     NaN       NaN
# dol_vehicle_id           NaN     NaN       NaN
# vehicle_location         NaN     NaN       NaN
# electric_utility         NaN     NaN       NaN
# 2020_census_tract        NaN     NaN       NaN

# %% [markdown]
# - mostly categorical, nominal variables
# - each row represents each dol_vehicle_id
# - electric_range has values of 0, which is technically null
#     - "Electric Range is no longer maintained for Battery Electric Vehicles (BEV) because new BEVs have an electric range of 30 miles or more. Zero (0) will be entered where the electric range has not been researched."
# - model year 2025??

# %%
# vin
ev['vin'].value_counts()
# Out:
# vin
# 7SAYGDEE6P    1221
# 7SAYGDEE7P    1217
# 7SAYGDEEXP    1181
# 7SAYGDEE5P    1176
# 7SAYGDEE8P    1174
#               ...
# YV4BC0PM5G       1
# YV4ER3GL1R       1
# WP0AB2Y12S       1
# SALWV2RY9L       1
# WA1LAAGE5M       1
# Name: count, Length: 12140, dtype: int64

# %%
# dol_vehicle_id
ev['dol_vehicle_id'].value_counts()
# Out:
# dol_vehicle_id
# 240684006    1
# 249393770    1
# 150024689    1
# 261919150    1
# 251776654    1
#             ..
# 251346868    1
# 266996754    1
# 212936545    1
# 207564941    1
# 228335040    1
# Name: count, Length: 205439, dtype: int64

# %%
# vin and vehicle id pairs
ev[['vin','dol_vehicle_id']].value_counts()
# Out:
# vin         dol_vehicle_id
# 1C4JJXN60P  227539357         1
# 7SAYGDEE5P  270935024         1
#             264911223         1
#             265823974         1
#             266835145         1
#                              ..
# 5YJ3E1EA8P  254972210         1
#             255011914         1
#             255028728         1
#             255122115         1
# ZFAFFAC49R  270956304         1
# Name: count, Length: 205439, dtype: int64

# %%
# check vin with multiple vehicle ids
cond = ev['vin'].str.contains('7SAYGDEE')
ev[cond].sort_values('vin')
# Out:
#                vin     county         city state postal_code  model_year  \
# 185035  7SAYGDEE0N  Snohomish      Bothell    WA       98021        2022
# 56720   7SAYGDEE0N       King    Sammamish    WA       98075        2022
# 200126  7SAYGDEE0N     Pierce   Gig Harbor    WA       98332        2022
# 140167  7SAYGDEE0N       King      Seattle    WA       98109        2022
# 127606  7SAYGDEE0N  Snohomish      Everett    WA       98204        2022
# ...            ...        ...          ...   ...         ...         ...
# 96597   7SAYGDEEXR  Snohomish      Everett    WA       98208        2024
# 152463  7SAYGDEEXR    Cowlitz  Castle Rock    WA       98611        2024
# 147022  7SAYGDEEXR       King      Seattle    WA       98108        2024
# 70329   7SAYGDEEXR       King    Sammamish    WA       98075        2024
# 100390  7SAYGDEEXR      Clark    Vancouver    WA       98685        2024
#
#          make    model                         ev_type  \
# 185035  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 56720   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 200126  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 140167  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 127606  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# ...       ...      ...                             ...
# 96597   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 152463  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 147022  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 70329   TESLA  MODEL Y  Battery Electric Vehicle (BEV)
# 100390  TESLA  MODEL Y  Battery Electric Vehicle (BEV)
#
#                                          cafv_eligibility  electric_range  \
# 185035  Eligibility unknown as battery range has not b...             0.0
# 56720   Eligibility unknown as battery range has not b...             0.0
# 200126  Eligibility unknown as battery range has not b...             0.0
# 140167  Eligibility unknown as battery range has not b...             0.0
# 127606  Eligibility unknown as battery range has not b...             0.0
# ...                                                   ...             ...
# 96597   Eligibility unknown as battery range has not b...             0.0
# 152463  Eligibility unknown as battery range has not b...             0.0
# 147022  Eligibility unknown as battery range has not b...             0.0
# 70329   Eligibility unknown as battery range has not b...             0.0
# 100390  Eligibility unknown as battery range has not b...             0.0
#
#         base_msrp legislative_district dol_vehicle_id  \
# 185035        0.0                    1      212134100
# 56720         0.0                   41      219109110
# 200126        0.0                   26      193710912
# 140167        0.0                   36      203250785
# 127606        0.0                   21      193753003
# ...           ...                  ...            ...
# 96597         0.0                   44      267607455
# 152463        0.0                   20      270054522
# 147022        0.0                   37      264441943
# 70329         0.0                   41      265096870
# 100390        0.0                   18      268083644
#
#                        vehicle_location  \
# 185035  POINT (-122.2107298 47.7977268)
# 56720   POINT (-122.0181135 47.5880568)
# 200126  POINT (-122.5966931 47.3616785)
# 140167  POINT (-122.3441532 47.6305366)
# 127606  POINT (-122.2507211 47.8976713)
# ...                                 ...
# 96597   POINT (-122.2032349 47.8956271)
# 152463   POINT (-122.893877 46.2844051)
# 147022  POINT (-122.3173531 47.5484673)
# 70329   POINT (-122.0181135 47.5880568)
# 100390    POINT (-122.688741 45.711311)
#
#                                          electric_utility 2020_census_tract
# 185035                             PUGET SOUND ENERGY INC       53061051938
# 56720       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032213
# 200126  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       53053072508
# 140167       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033006702
# 127606                             PUGET SOUND ENERGY INC       53061041813
# ...                                                   ...               ...
# 96597                              PUGET SOUND ENERGY INC       53061041606
# 152463  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53015002003
# 147022       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033010101
# 70329       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032213
# 100390  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011040908
#
# [21744 rows x 17 columns]

# %%
# county
ev['county'].value_counts().nlargest(10)
# Out:
# county
# King         105237
# Snohomish     24721
# Pierce        16197
# Clark         12231
# Thurston       7526
# Kitsap         6848
# Spokane        5460
# Whatcom        4978
# Benton         2546
# Skagit         2266
# Name: count, dtype: int64

# %%
# city
ev['city'].value_counts().nlargest(10)
# Out:
# city
# Seattle      33328
# Bellevue     10235
# Redmond       7341
# Vancouver     7286
# Bothell       6769
# Kirkland      5998
# Renton        5986
# Sammamish     5908
# Olympia       4966
# Tacoma        4321
# Name: count, dtype: int64

# %%
# model_year
ev['model_year'].value_counts().nlargest(10)
# Out:
# model_year
# 2023    60161
# 2024    30030
# 2022    28465
# 2021    19837
# 2018    14386
# 2020    12241
# 2019    10872
# 2017     8662
# 2016     5474
# 2015     4741
# Name: count, dtype: int64

# %%
# make
ev['make'].value_counts().nlargest(10)
# Out:
# make
# TESLA         90318
# CHEVROLET     15114
# NISSAN        14525
# FORD          10840
# KIA            9104
# BMW            8481
# TOYOTA         7945
# HYUNDAI        5782
# RIVIAN         5679
# VOLKSWAGEN     5638
# Name: count, dtype: int64

# %%
# model
ev['model'].value_counts().nlargest(10)
# Out:
# model
# MODEL Y           43437
# MODEL 3           32113
# LEAF              13488
# MODEL S            7881
# BOLT EV            6727
# MODEL X            6249
# VOLT               4829
# ID.4               4564
# MUSTANG MACH-E     4154
# WRANGLER           4047
# Name: count, dtype: int64

# %%
# check if each vin has different models
grouped = ev.groupby('vin')['model'].nunique()
grouped[grouped > 1]
# Out:
# Series([], Name: model, dtype: int64)

# %%
# ev_type
ev['ev_type'].value_counts()
# Out:
# ev_type
# Battery Electric Vehicle (BEV)            161539
# Plug-in Hybrid Electric Vehicle (PHEV)     43900
# Name: count, dtype: int64

# %% [markdown]
# There are only two types of vehicle in this dataset
# 1) Battery Electric Vehicle (BEV)
# - "A Battery Electric Vehicle (BEV) is an all-electric vehicle using one or more batteries to store the electrical energy that powers the motor and is charged by plugging the vehicle in to an electric power source."
# - which is a general Electric (EV)
# 2) Plug-in Hybrid Electric Vehicle (PHEV)
# - "A Plug-in Hybrid Electric Vehicle (PHEV) is a vehicle that uses one or more batteries to power an electric motor; uses another fuel, such as gasoline or diesel, to power an internal combustion engine or other propulsion source; and is charged by plugging the vehicle in to an electric power source."

# %%
# cafv_eligibility
ev['cafv_eligibility'].value_counts()
# Out:
# cafv_eligibility
# Eligibility unknown as battery range has not been researched    114172
# Clean Alternative Fuel Vehicle Eligible                          70016
# Not eligible due to low battery range                            21251
# Name: count, dtype: int64

# %%
# electric_range
ev['electric_range'].value_counts()
# Out:
# electric_range
# 0.0      114172
# 215.0      6426
# 32.0       4895
# 25.0       4429
# 21.0       4220
#           ...
# 46.0          4
# 11.0          4
# 95.0          3
# 57.0          2
# 43.0          1
# Name: count, Length: 105, dtype: int64

# %%
ev['electric_range'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# - many rows with 0 electric_range

# %%
# maker/brand that has higher electric range
cond = ev['electric_range'] != 0.0
ev[cond].groupby('make')['electric_range'].mean().sort_values(ascending=False)
# Out:
# make
# TESLA                   241.101287
# JAGUAR                  234.000000
# POLESTAR                233.000000
# CHEVROLET               141.599897
# VOLKSWAGEN              107.363128
# NISSAN                  104.908616
# WHEEGO ELECTRIC CARS    100.000000
# TH!NK                   100.000000
# FIAT                     85.623077
# KIA                      84.168486
# HYUNDAI                  84.110837
# AUDI                     78.316574
# PORSCHE                  71.775862
# SMART                    61.878543
# AZURE DYNAMICS           56.000000
# MINI                     48.738095
# HONDA                    46.572261
# BMW                      46.346467
# LEXUS                    36.892421
# CADILLAC                 36.681818
# MERCEDES-BENZ            34.642292
# ALFA ROMEO               33.000000
# FISKER                   33.000000
# CHRYSLER                 32.176821
# DODGE                    32.000000
# TOYOTA                   31.078312
# MITSUBISHI               30.987230
# LAND ROVER               28.971014
# MAZDA                    26.000000
# VOLVO                    25.683939
# FORD                     25.577924
# LINCOLN                  23.715719
# JEEP                     22.329207
# BENTLEY                  22.000000
# SUBARU                   17.000000
# Name: electric_range, dtype: float64

# %%
# base_msrp
ev['base_msrp'].value_counts()
# Out:
# base_msrp
# 0.0         202114
# 69900.0       1359
# 31950.0        365
# 52900.0        220
# 32250.0        138
# 59900.0        128
# 54950.0        124
# 39995.0        116
# 36900.0        103
# 44100.0         99
# 64950.0         86
# 45600.0         81
# 52650.0         72
# 33950.0         71
# 34995.0         64
# 55700.0         54
# 36800.0         52
# 53400.0         39
# 81100.0         23
# 110950.0        21
# 98950.0         21
# 90700.0         16
# 102000.0        13
# 75095.0         11
# 184400.0        10
# 43700.0          9
# 89100.0          8
# 109000.0         6
# 91250.0          4
# 32995.0          3
# 845000.0         1
# Name: count, dtype: int64

# %%
ev['base_msrp'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# - many rows with 0 base_msrp

# %%
# maker/brand that has higher electric range
cond = ev['base_msrp'] != 0.0
ev[cond].groupby('make')['base_msrp'].mean().sort_values(ascending=False)
# Out:
# make
# PORSCHE                 133950.000000
# FISKER                  102000.000000
# CADILLAC                 75095.000000
# TESLA                    70177.980456
# VOLVO                    56286.601307
# BMW                      52720.948617
# CHRYSLER                 39995.000000
# MINI                     36866.451613
# SUBARU                   34995.000000
# WHEEGO ELECTRIC CARS     32995.000000
# KIA                      32269.512195
# MERCEDES-BENZ                     NaN
# Name: base_msrp, dtype: float64

# %%
# the number of electrical vehicles by each district
ev_by_district = ev['legislative_district'].value_counts().rename('ev_count')
ev_by_district
# Out:
# legislative_district
# 41    12994
# 45    12003
# 48    11184
# 1      8946
# 5      8787
# 11     8773
# 36     8297
# 46     7790
# 43     7236
# 37     5994
# 34     5933
# 44     5565
# 18     5508
# 21     5188
# 22     5122
# 32     5014
# 23     4409
# 40     4303
# 26     4095
# 47     3772
# 33     3739
# 31     3684
# 10     3566
# 17     3477
# 39     3045
# 35     2952
# 42     2930
# 49     2913
# 27     2865
# 24     2749
# 28     2698
# 30     2504
# 2      2424
# 25     2219
# 38     2161
# 8      2158
# 6      2004
# 12     1934
# 20     1929
# 4      1810
# 13     1503
# 29     1443
# 14     1356
# 19     1248
# 9      1171
# 16     1080
# 3      1012
# 7       973
# 15      537
# Name: ev_count, dtype: int64

# %% [markdown]
# - legislative district values are numbers only

# %%
# ev by county
ev_by_county = ev['county'].value_counts().rename('ev_count')
ev_by_county
# Out:
# county
# King           105237
# Snohomish       24721
# Pierce          16197
# Clark           12231
# Thurston         7526
#                 ...
# Maui                1
# Plaquemines         1
# Burlington          1
# Mobile              1
# Christian           1
# Name: ev_count, Length: 205, dtype: int64

# %%
get_heatmap(ev)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Missing values

# %%
# check null heatmap
temp = ev.isna()
print(temp.sum())
sns.heatmap(temp);
# Out:
# vin                       0
# county                    3
# city                      3
# state                     0
# postal_code               3
# model_year                0
# make                      0
# model                     1
# ev_type                   0
# cafv_eligibility          0
# electric_range            8
# base_msrp                 8
# legislative_district    442
# dol_vehicle_id            0
# vehicle_location          8
# electric_utility          3
# 2020_census_tract         3
# dtype: int64

# %% [markdown]
# - cannot really see null distribution through the heatmap

# %%
# null for county, city, postal code, electric_utility, and 2020_census_tract

cond = ev['county'].isna() | ev['city'].isna() | ev['postal_code'].isna() | ev['electric_utility'].isna() | ev['2020_census_tract'].isna()
temp = ev[cond]
print(temp.shape)
temp
# Out:
# (3, 17)
#                vin county city state postal_code  model_year       make  \
# 138102  WBAJA9C50K    NaN  NaN    AE         NaN        2019        BMW
# 182254  5YJXCAE24H    NaN  NaN    BC         NaN        2017      TESLA
# 203466  1G1RB6S53J    NaN  NaN    BC         NaN        2018  CHEVROLET
#
#           model                                 ev_type  \
# 138102     530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 182254  MODEL X          Battery Electric Vehicle (BEV)
# 203466     VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                                cafv_eligibility  electric_range  base_msrp  \
# 138102    Not eligible due to low battery range            16.0    53400.0
# 182254  Clean Alternative Fuel Vehicle Eligible           200.0        0.0
# 203466  Clean Alternative Fuel Vehicle Eligible            53.0        0.0
#
#        legislative_district dol_vehicle_id vehicle_location electric_utility  \
# 138102                  NaN      244582593              NaN              NaN
# 182254                  NaN      159850029              NaN              NaN
# 203466                  NaN      477613216              NaN              NaN
#
#        2020_census_tract
# 138102               NaN
# 182254               NaN
# 203466               NaN

# %% [markdown]
# - 3 data where county, city, postal code, electric_utility, and 2020_census_tract are null
# - all from differnet state
# - --> remove

# %%
# null for model
cond = ev['model'].isna()
ev[cond]
# Out:
#               vin county       city state postal_code  model_year make model  \
# 43570  1GT10DDB5S  Clark  Vancouver    WA       98663        2025  GMC   NaN
#
#                               ev_type  \
# 43570  Battery Electric Vehicle (BEV)
#
#                                         cafv_eligibility  electric_range  \
# 43570  Eligibility unknown as battery range has not b...             0.0
#
#        base_msrp legislative_district dol_vehicle_id  \
# 43570        0.0                   49      269752913
#
#                     vehicle_location  \
# 43570  POINT (-122.657848 45.654422)
#
#                                         electric_utility 2020_census_tract
# 43570  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011041011

# %%
ev[ev['make'] == 'GMC']['model'].value_counts()
# Out:
# model
# HUMMER EV PICKUP    34
# Name: count, dtype: int64

# %% [markdown]
# - In this dataset, all the electric vehicles made by GMC is 'HUMMER EV PICKUP'
# - --> Therefore, will fill the null value as 'HUMMER EV PICKUP'

# %%
# null for electric_range and base_msrp       
cond = ev['electric_range'].isna() | ev['base_msrp'].isna()
temp = ev[cond]
print(temp.shape)
temp
# Out:
# (8, 17)
#                vin     county        city state postal_code  model_year  \
# 31588   W1K6G8CB9R       King  Des Moines    WA       98198        2024
# 82616   W1K6G8CB7R      Clark   Vancouver    WA       98664        2024
# 84294   W1K6G8CB9R      Clark   Vancouver    WA       98664        2024
# 91234   W1K6G8CB2R      Clark   Vancouver    WA       98664        2024
# 125730  W1K6G8CB3R       King      Auburn    WA       98092        2024
# 127349  W1K6G8CB3R  Snohomish     Woodway    WA       98020        2024
# 148606  W1K6G8CB5R     Pierce      Tacoma    WA       98405        2024
# 159687  W1K6G8CB5R       King     Seattle    WA       98118        2024
#
#                  make    model                                 ev_type  \
# 31588   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 82616   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 84294   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 91234   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 125730  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 127349  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 148606  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 159687  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                                cafv_eligibility  electric_range  base_msrp  \
# 31588   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 82616   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 84294   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 91234   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 125730  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 127349  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 148606  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 159687  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
#
#        legislative_district dol_vehicle_id                 vehicle_location  \
# 31588                    33      268383069  POINT (-122.3145447 47.3984346)
# 82616                    49      267549005    POINT (-122.575383 45.620105)
# 84294                    49      271731323    POINT (-122.575383 45.620105)
# 91234                    49      270010520    POINT (-122.575383 45.620105)
# 125730                   31      269271873  POINT (-122.1550193 47.2884536)
# 127349                   32      268002164   POINT (-122.3757836 47.800042)
# 148606                   27      273293821       POINT (-122.46564 47.2457)
# 159687                   37      269456498  POINT (-122.2753318 47.5411053)
#
#                                          electric_utility 2020_census_tract
# 31588       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033029001
# 82616   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011043100
# 84294   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011043100
# 91234   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011043100
# 125730      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033031204
# 127349                             PUGET SOUND ENERGY INC       53061050600
# 148606  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       53053061300
# 159687       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033011802

# %%
cond = (ev['model_year'] == 2024) & (ev['make'] == 'MERCEDES-BENZ') & (ev['model'] == 'S-CLASS')
ev[cond]
# Out:
#                vin     county        city state postal_code  model_year  \
# 13273   W1K6G6KB0R  Snohomish     Everett    WA       98208        2024
# 31588   W1K6G8CB9R       King  Des Moines    WA       98198        2024
# 57148   W1K6G6KB8R       King    Kirkland    WA       98033        2024
# 74028   W1K6G6KBXR       King     Seattle    WA       98117        2024
# 82616   W1K6G8CB7R      Clark   Vancouver    WA       98664        2024
# 84294   W1K6G8CB9R      Clark   Vancouver    WA       98664        2024
# 91234   W1K6G8CB2R      Clark   Vancouver    WA       98664        2024
# 125730  W1K6G8CB3R       King      Auburn    WA       98092        2024
# 127349  W1K6G8CB3R  Snohomish     Woodway    WA       98020        2024
# 148606  W1K6G8CB5R     Pierce      Tacoma    WA       98405        2024
# 159687  W1K6G8CB5R       King     Seattle    WA       98118        2024
# 173096  W1K6G6KB7R       King     Redmond    WA       98053        2024
#
#                  make    model                                 ev_type  \
# 13273   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 31588   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 57148   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 74028   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 82616   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 84294   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 91234   MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 125730  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 127349  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 148606  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 159687  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 173096  MERCEDES-BENZ  S-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                                cafv_eligibility  electric_range  base_msrp  \
# 13273   Clean Alternative Fuel Vehicle Eligible            46.0        0.0
# 31588   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 57148   Clean Alternative Fuel Vehicle Eligible            46.0        0.0
# 74028   Clean Alternative Fuel Vehicle Eligible            46.0        0.0
# 82616   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 84294   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 91234   Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 125730  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 127349  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 148606  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 159687  Clean Alternative Fuel Vehicle Eligible             NaN        NaN
# 173096  Clean Alternative Fuel Vehicle Eligible            46.0        0.0
#
#        legislative_district dol_vehicle_id                 vehicle_location  \
# 13273                    21      261762462  POINT (-122.2032349 47.8956271)
# 31588                    33      268383069  POINT (-122.3145447 47.3984346)
# 57148                    45      269293412   POINT (-122.1925969 47.676241)
# 74028                    36      263004689    POINT (-122.377938 47.690166)
# 82616                    49      267549005    POINT (-122.575383 45.620105)
# 84294                    49      271731323    POINT (-122.575383 45.620105)
# 91234                    49      270010520    POINT (-122.575383 45.620105)
# 125730                   31      269271873  POINT (-122.1550193 47.2884536)
# 127349                   32      268002164   POINT (-122.3757836 47.800042)
# 148606                   27      273293821       POINT (-122.46564 47.2457)
# 159687                   37      269456498  POINT (-122.2753318 47.5411053)
# 173096                   45      272030524    POINT (-122.030684 47.669552)
#
#                                          electric_utility 2020_census_tract
# 13273                              PUGET SOUND ENERGY INC       53061041808
# 31588       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033029001
# 57148       PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033022502
# 74028        CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033003000
# 82616   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011043100
# 84294   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011043100
# 91234   BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF C...       53011043100
# 125730      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033031204
# 127349                             PUGET SOUND ENERGY INC       53061050600
# 148606  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       53053061300
# 159687       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       53033011802
# 173096      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       53033032332

# %% [markdown]
# - all the data, where electric_range and base_msrp are null, in common has 2024 for model_year, MERCEDES-BENZ for make, S-CLASS for model
# - all the other 2024 benz s-class model has 46 for electric_range and 0 base_msrp, therefore, will replace the null with 46 and 0 respectively

# %%
# null for vehicle_location

cond = ev['vehicle_location'].isna()
temp = ev[cond]
print(temp.shape)
temp
# Out:
# (8, 17)
#                vin   county        city state postal_code  model_year  \
# 138046  KNDJX3AE8H  Pacific  Long Beach    WA       98634        2017
# 138102  WBAJA9C50K      NaN         NaN    AE         NaN        2019
# 148503  1C4JJXP69P  Pacific  Long Beach    WA       98634        2023
# 176278  1G1FW6S08N  Pacific  Long Beach    WA       98634        2022
# 178268  7SAYGDEE0N  Pacific  Long Beach    WA       98634        2022
# 178396  KMHE54L2XH  Pacific  Long Beach    WA       98634        2017
# 182254  5YJXCAE24H      NaN         NaN    BC         NaN        2017
# 203466  1G1RB6S53J      NaN         NaN    BC         NaN        2018
#
#              make     model                                 ev_type  \
# 138046        KIA   SOUL EV          Battery Electric Vehicle (BEV)
# 138102        BMW      530E  Plug-in Hybrid Electric Vehicle (PHEV)
# 148503       JEEP  WRANGLER  Plug-in Hybrid Electric Vehicle (PHEV)
# 176278  CHEVROLET   BOLT EV          Battery Electric Vehicle (BEV)
# 178268      TESLA   MODEL Y          Battery Electric Vehicle (BEV)
# 178396    HYUNDAI    SONATA  Plug-in Hybrid Electric Vehicle (PHEV)
# 182254      TESLA   MODEL X          Battery Electric Vehicle (BEV)
# 203466  CHEVROLET      VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                                          cafv_eligibility  electric_range  \
# 138046            Clean Alternative Fuel Vehicle Eligible            93.0
# 138102              Not eligible due to low battery range            16.0
# 148503              Not eligible due to low battery range            21.0
# 176278  Eligibility unknown as battery range has not b...             0.0
# 178268  Eligibility unknown as battery range has not b...             0.0
# 178396              Not eligible due to low battery range            27.0
# 182254            Clean Alternative Fuel Vehicle Eligible           200.0
# 203466            Clean Alternative Fuel Vehicle Eligible            53.0
#
#         base_msrp legislative_district dol_vehicle_id vehicle_location  \
# 138046    32250.0                   19      106442773              NaN
# 138102    53400.0                  NaN      244582593              NaN
# 148503        0.0                   19      254934886              NaN
# 176278        0.0                   19      218102209              NaN
# 178268        0.0                   19      211479649              NaN
# 178396        0.0                   19      245533578              NaN
# 182254        0.0                  NaN      159850029              NaN
# 203466        0.0                  NaN      477613216              NaN
#
#                                          electric_utility 2020_census_tract
# 138046  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       53049950501
# 138102                                                NaN               NaN
# 148503  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       53049950600
# 176278  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       53049950600
# 178268  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       53049950600
# 178396  BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF P...       53049950501
# 182254                                                NaN               NaN
# 203466                                                NaN               NaN

# %% [markdown]
# - 8 data where vehicle_location is null
# - 3 of them are from different states
# - vehicle location is not neccessary for my analysis
# - but if i will be using geo/map visualization methods and i feel like needing it,
#     - --> since they all are from legislative district 19, I can extract/get the central locaiton of them and using the valuue, I can fill the null

# %%
# null for legislative_district

cond = ev['legislative_district'].isna()
ev[cond][['state','electric_utility']].head()
# Out:
#       state                       electric_utility
# 26697    MO  NON WASHINGTON STATE ELECTRIC UTILITY
# 33457    CA  NON WASHINGTON STATE ELECTRIC UTILITY
# 38814    VA  NON WASHINGTON STATE ELECTRIC UTILITY
# 40765    NC  NON WASHINGTON STATE ELECTRIC UTILITY
# 42678    MD  NON WASHINGTON STATE ELECTRIC UTILITY

# %% [markdown]
# - different states
#     - "NON WASHINGTON STATE ELECTRIC UTILITY"
# - --> remove

# %% [markdown]
# Handling missing values:
# - Remove rows where multiple columns are simultaneously null.
# - Handle missing values for the model of GMC vehicles.
# - Handle missing values for the electric_range and base_msrp of Mercedes-Benz S-CLASS.
# - Remove rows where legislative_district is null.
#
# Handling outliers
# - For numerical variables: Identify and handle outliers using the IQR method.
# - For categorical variables: Identify categories with very low frequencies and replace them with 'Other'.

# %%
# Handle missing values
# county, city, postal code, electric_utility, 2020_census_tract -> remove null
ev = ev.dropna(subset=['county', 'city', 'postal_code', 'electric_utility', '2020_census_tract'], how='all')

# model -> impute
ev.loc[ev['make'] == 'GMC', 'model'] = ev.loc[ev['make'] == 'GMC', 'model'].fillna('HUMMER EV PICKUP')

# electric_range, base_msrp -> impute
cond = (ev['model_year'] == 2024) & (ev['make'] == 'MERCEDES-BENZ') & (ev['model'] == 'S-CLASS')
ev.loc[cond, 'electric_range'] = ev.loc[cond, 'electric_range'].fillna(46)
ev.loc[cond, 'base_msrp'] = ev.loc[cond, 'base_msrp'].fillna(0)

# vehicle_location
# -> later, if necessary

# legislative_district -> drop null
ev = ev.dropna(subset=['legislative_district'])

# after preprocessing
print("\nData shape after preprocessing:", ev.shape)
print("\nNull values after preprocessing:")
print(ev.isnull().sum())
# Out:
# Data shape after preprocessing: (204997, 17)
#
# Null values after preprocessing:
# vin                     0
# county                  0
# city                    0
# state                   0
# postal_code             0
# model_year              0
# make                    0
# model                   0
# ev_type                 0
# cafv_eligibility        0
# electric_range          0
# base_msrp               0
# legislative_district    0
# dol_vehicle_id          0
# vehicle_location        5
# electric_utility        0
# 2020_census_tract       0
# dtype: int64

# %% [markdown]
# ### Outliers

# %%
# Check outliers

# Numeric columns
numeric_columns = ['model_year', 'electric_range', 'base_msrp']

# IQR based outlier check
for col in numeric_columns:
    Q1 = ev[col].quantile(0.25)
    Q3 = ev[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    print(f"\nOutliers in {col}:")
    print(ev[(ev[col] < lower_bound) | (ev[col] > upper_bound)][col].describe())
    
    # replace with lower bound and upper bound
    # ev[col] = ev[col].clip(lower_bound, upper_bound)
# Out:
# Outliers in model_year:
# count    2317.000000
# mean     2011.558481
# std         1.117711
# min      1997.000000
# 25%      2011.000000
# 50%      2012.000000
# 75%      2012.000000
# max      2012.000000
# Name: model_year, dtype: float64
#
# Outliers in electric_range:
# count    36860.000000
# mean       230.216007
# std         44.796092
# min        124.000000
# 25%        210.000000
# 50%        220.000000
# 75%        259.000000
# max        337.000000
# Name: electric_range, dtype: float64
#
# Outliers in base_msrp:
# count      3317.000000
# mean      57143.542358
# std       22772.943759
# min       31950.000000
# 25%       39995.000000
# 50%       59900.000000
# 75%       69900.000000
# max      845000.000000
# Name: base_msrp, dtype: float64

# %%
# Categorical columns
categorical_columns = ['county', 'city', 'make', 'model', 'ev_type', 'cafv_eligibility', 'electric_utility']

for col in categorical_columns:
    value_counts = ev[col].value_counts()
    rare_categories = value_counts[value_counts < len(ev) * 0.01].index  # below 1% frequency
    print(f"\nRare categories in {col}:")
    print(rare_categories)
    
    # replace with 'Other'
    # ev[col] = ev[col].replace(rare_categories, 'Other')
# Out:
# Rare categories in county:
# Index(['Chelan', 'Yakima', 'Clallam', 'Jefferson', 'Cowlitz', 'San Juan',
#        'Mason', 'Lewis', 'Kittitas', 'Grays Harbor',
#        ...
#        'Richland', 'Sarpy', 'Rockdale', 'Rockingham', 'Lane', 'Maui',
#        'Plaquemines', 'Burlington', 'Mobile', 'Christian'],
#       dtype='object', name='county', length=194)
#
# Rare categories in city:
# Index(['Bainbridge Island', 'Camas', 'Maple Valley', 'Federal Way',
#        'Lake Stevens', 'Bremerton', 'Puyallup', 'Marysville', 'Port Orchard',
#        'Seatac',
#        ...
#        'Reno', 'Lompoc', 'Dover', 'Martha Lake', 'North Las Vegas', 'Peoria',
#        'Winterville', 'Sarasota', 'Aberdeen Proving Ground', 'Wishram'],
#       dtype='object', name='city', length=746)
#
# Rare categories in make:
# Index(['MERCEDES-BENZ', 'SUBARU', 'PORSCHE', 'POLESTAR', 'HONDA', 'MITSUBISHI',
#        'MINI', 'FIAT', 'LEXUS', 'CADILLAC', 'MAZDA', 'DODGE', 'LINCOLN',
#        'LUCID', 'GENESIS', 'SMART', 'JAGUAR', 'FISKER', 'ALFA ROMEO',
#        'LAND ROVER', 'GMC', 'ACURA', 'TH!NK', 'BENTLEY', 'AZURE DYNAMICS',
#        'WHEEGO ELECTRIC CARS', 'ROLLS-ROYCE', 'RAM'],
#       dtype='object', name='make')
#
# Rare categories in model:
# Index(['R1T', 'I3', 'FUSION', 'XC90', 'C-MAX', 'GRAND CHEROKEE', 'I4', 'XC60',
#        'SOLTERRA', 'PS2',
#        ...
#        'WHEEGO', 'FLYING SPUR', '750E', '745LE', 'SPECTRE', 'A8 E',
#        'PROMASTER 3500', '918', 'S-10 PICKUP', 'ESPRINTER'],
#       dtype='object', name='model', length=132)
#
# Rare categories in ev_type:
# Index([], dtype='object', name='ev_type')
#
# Rare categories in cafv_eligibility:
# Index([], dtype='object', name='cafv_eligibility')
#
# Rare categories in electric_utility:
# Index(['BONNEVILLE POWER ADMINISTRATION||PUD 1 OF SNOHOMISH COUNTY',
#        'PACIFICORP',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF BENTON COUNTY',
#        'MODERN ELECTRIC WATER COMPANY', 'PUD NO 1 OF CHELAN COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUGET SOUND ENERGY INC||PUD NO 1 OF JEFFERSON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF COWLITZ COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF RICHLAND - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||ORCAS POWER & LIGHT COOP',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF CLALLAM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 3 OF MASON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF GRAYS HARBOR COUNTY',
#        'PUD NO 2 OF GRANT COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF FRANKLIN COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||ELMHURST MUTUAL POWER & LIGHT CO|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||VERA IRRIGATION DISTRICT #15',
#        'AVISTA CORP', 'NON WASHINGTON STATE ELECTRIC UTILITY',
#        'PUD NO 1 OF DOUGLAS COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 1 OF LEWIS COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||INLAND POWER & LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KLICKITAT COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF CENTRALIA - (WA)|CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PACIFICORP||PUD NO 1 OF CLARK COUNTY - (WA)',
#        'CITY OF TACOMA - (WA)||TANNER ELECTRIC COOP',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF PORT ANGELES - (WA)',
#        'NO KNOWN ELECTRIC UTILITY SERVICE',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 2 OF PACIFIC COUNTY',
#        'CITY OF BLAINE - (WA)||PUD NO 1 OF WHATCOM COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF SKAMANIA CO',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||LAKEVIEW LIGHT & POWER|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||TOWN OF STEILACOOM|CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#        'OKANOGAN COUNTY ELEC COOP, INC',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF ELLENSBURG - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||OHOP MUTUAL LIGHT COMPANY, INC|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PACIFICORP||BENTON RURAL ELECTRIC ASSN',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PUD NO 1 OF MASON COUNTY',
#        'PUD NO 1 OF OKANOGAN COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||PARKLAND LIGHT & WATER COMPANY|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF MILTON - (WA)|CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||PUD NO 1 OF ASOTIN COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF WAHKIAKUM COUNTY',
#        'PUD NO 1 OF PEND OREILLE COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||AVISTA CORP||BIG BEND ELECTRIC COOP, INC',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||BENTON RURAL ELECTRIC ASSN|PENINSULA LIGHT COMPANY',
#        'PUD NO 1 OF WHATCOM COUNTY', 'CITY OF CHENEY - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||TOWN OF RUSTON - (WA)|CITY OF TACOMA - (WA)||PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||BIG BEND ELECTRIC COOP, INC',
#        'BONNEVILLE POWER ADMINISTRATION||TOWN OF EATONVILLE - (WA)|CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF MASON COUNTY|PUD NO 1 OF JEFFERSON COUNTY',
#        'CITY OF TACOMA - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF FERRY COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||COLUMBIA RURAL ELEC ASSN, INC',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF MCCLEARY - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF KITTITAS COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PACIFICORP||COLUMBIA RURAL ELEC ASSN, INC',
#        'CITY OF CHEWELAH', 'CITY OF SUMAS - (WA)||PUD NO 1 OF WHATCOM COUNTY',
#        'PORTLAND GENERAL ELECTRIC CO',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF COULEE DAM - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||BENTON RURAL ELECTRIC ASSN',
#        'BONNEVILLE POWER ADMINISTRATION||NESPELEM VALLEY ELEC COOP, INC',
#        'CITY OF SEATTLE - (WA)',
#        'BONNEVILLE POWER ADMINISTRATION||CITY OF TACOMA - (WA)||ALDER MUTUAL LIGHT CO, INC|PENINSULA LIGHT COMPANY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF JEFFERSON COUNTY',
#        'BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF ASOTIN COUNTY'],
#       dtype='object', name='electric_utility')

# %% [markdown]
# - There are outliers in several columns

# %%
import pickle

with open('data/ev.pickle', 'wb') as f:
    pickle.dump(ev, f)

# with open('data/ev.pickle', 'rb') as f:
#     ev = pickle.load(f)

# %% [markdown]
# ---
# # 2022 General Election Results in Washington State
#
# - United States state legislative elections (US Senator election) occurred in 2022 in the Washington state

# %%
# 2022 election results by legislative district
elec = pd.read_excel('data/2022gen results by legislative district.xlsx', sheet_name='FINAL by LD', header=[1], nrows=49)
# filter columns
include_cols = ['District Name','Registered Voters','Ballots Cast','% Turnout','Patty Murray','Tiffany Smiley']
elec = elec[include_cols]
# lower columns
elec.columns = ['_'.join(col.strip().lower().split()) for col in elec.columns]
# rename columns
elec.rename(columns={'district_name':'legislative_district'}, inplace=True)

elec.head(1)
# Out:
#      legislative_district  registered_voters  ballots_cast  %_turnout  \
# 0  Legislative District 1              99789         69622   0.697692
#
#    patty_murray  tiffany_smiley
# 0         48493           20631

# %%
elec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   legislative_district  49 non-null     object
#  1   registered_voters     49 non-null     int64
#  2   ballots_cast          49 non-null     int64
#  3   %_turnout             49 non-null     float64
#  4   patty_murray          49 non-null     int64
#  5   tiffany_smiley        49 non-null     int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.4+ KB

# %%
# 2022 election results by county
elec_county = pd.read_excel('data/2022gen results by legislative district.xlsx', sheet_name='FINAL by LD, County', header=[1])
elec_county = elec_county.dropna(axis=0, how='all')
elec_county = elec_county.dropna(subset='County')
# filter columns
include_cols = ['County','Registered Voters','Ballots Cast','Patty Murray','Tiffany Smiley']
elec_county = elec_county[include_cols]
# aggregate by couty
elec_county = elec_county.groupby('County')[['Registered Voters','Ballots Cast','Patty Murray','Tiffany Smiley']].sum().reset_index()

# Add % Turnout column
elec_county['% Turnout'] = elec_county['Ballots Cast'] / elec_county['Registered Voters']
elec_county = elec_county[['County','Registered Voters','Ballots Cast','% Turnout','Patty Murray','Tiffany Smiley']] # reorder columns

# lower columns
elec_county.columns = ['_'.join(col.strip().lower().split()) for col in elec_county.columns]

elec_county.head(1)
# Out:
#   county  registered_voters  ballots_cast  %_turnout  patty_murray  \
# 0  Adams             7863.0        4163.0   0.529442         969.0
#
#    tiffany_smiley
# 0          3150.0

# %%
elec_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   county             39 non-null     object
#  1   registered_voters  39 non-null     float64
#  2   ballots_cast       39 non-null     float64
#  3   %_turnout          39 non-null     float64
#  4   patty_murray       39 non-null     float64
#  5   tiffany_smiley     39 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 2.0+ KB

# %%
elec_county.describe()
# Out:
#        registered_voters   ballots_cast  %_turnout   patty_murray  \
# count       3.900000e+01      39.000000  39.000000      39.000000
# mean        1.232534e+05   78658.615385   0.663833   44662.230769
# std         2.458092e+05  157389.846371   0.068297  111781.273116
# min         1.685000e+03    1316.000000   0.497804     307.000000
# 25%         1.538600e+04   11519.000000   0.626494    5036.500000
# 50%         4.286000e+04   24433.000000   0.664333   10039.000000
# 75%         1.058265e+05   60396.000000   0.708227   24596.500000
# max         1.384280e+06  896022.000000   0.782490  668692.000000
#
#        tiffany_smiley
# count       39.000000
# mean     33315.948718
# std      48584.589361
# min        977.000000
# 25%       5980.500000
# 50%      15612.000000
# 75%      33817.000000
# max     220307.000000

# %%
get_heatmap(elec)

# %%
get_heatmap(elec_county)

# %% [markdown]
# ## Feature Engineering

# %%
# keep only number value in district column for merge with main table
elec['legislative_district'] = elec['legislative_district'].apply(lambda x: x.split()[-1])
elec.head(1)
# Out:
#   legislative_district  registered_voters  ballots_cast  %_turnout  \
# 0                    1              99789         69622   0.697692
#
#    patty_murray  tiffany_smiley
# 0         48493           20631

# %%
# create a column of election winner party

def find_winner(df):
    if df['patty_murray'] > df['tiffany_smiley']:
        return 'Democratic'
    else:
        return 'Republican'

elec['party_won'] = elec.apply(find_winner, axis=1)
elec.head(1)
# Out:
#   legislative_district  registered_voters  ballots_cast  %_turnout  \
# 0                    1              99789         69622   0.697692
#
#    patty_murray  tiffany_smiley   party_won
# 0         48493           20631  Democratic

# %%
elec_county['party_won'] = elec_county.apply(find_winner, axis=1)
elec_county.head(1)
# Out:
#   county  registered_voters  ballots_cast  %_turnout  patty_murray  \
# 0  Adams             7863.0        4163.0   0.529442         969.0
#
#    tiffany_smiley   party_won
# 0          3150.0  Republican

# %%
# add ev count as a new column to the election result table
elec_ev_added = pd.merge(left=ev_by_district, right=elec, how='inner', on='legislative_district') # inner join
print(elec_ev_added.shape)
elec_ev_added.head(1)
# Out:
# (49, 8)
#   legislative_district  ev_count  registered_voters  ballots_cast  %_turnout  \
# 0                   41     12994              98278         65840   0.669936
#
#    patty_murray  tiffany_smiley   party_won
# 0         45730           19526  Democratic

# %%
elec_county_ev_added = pd.merge(left=ev_by_county, right=elec_county, how='inner', on='county') # inner join
print(elec_county_ev_added.shape)
elec_county_ev_added.head(1)
# Out:
# (39, 8)
#   county  ev_count  registered_voters  ballots_cast  %_turnout  patty_murray  \
# 0   King    105237          1384280.0      896022.0   0.647284      668692.0
#
#    tiffany_smiley   party_won
# 0        220307.0  Democratic

# %%
get_heatmap(elec_ev_added)

# %%
get_heatmap(elec_county_ev_added)

# %% [markdown]
# ## Merge

# %%
ev.head(1)
# Out:
#           vin  county     city state postal_code  model_year    make  \
# 0  JTMAB3FV3P  Kitsap  Seabeck    WA       98380        2023  TOYOTA
#
#         model                                 ev_type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                           cafv_eligibility  electric_range  base_msrp  \
# 0  Clean Alternative Fuel Vehicle Eligible            42.0        0.0
#
#   legislative_district dol_vehicle_id                 vehicle_location  \
# 0                   35      240684006  POINT (-122.8728334 47.5798304)
#
#          electric_utility 2020_census_tract
# 0  PUGET SOUND ENERGY INC       53035091301

# %%
elec.head(1)
# Out:
#   legislative_district  registered_voters  ballots_cast  %_turnout  \
# 0                    1              99789         69622   0.697692
#
#    patty_murray  tiffany_smiley   party_won
# 0         48493           20631  Democratic

# %%
elec_county.head(1)
# Out:
#   county  registered_voters  ballots_cast  %_turnout  patty_murray  \
# 0  Adams             7863.0        4163.0   0.529442         969.0
#
#    tiffany_smiley   party_won
# 0          3150.0  Republican

# %%
# add elecion data to the main, ev table
ev_elec = pd.merge(left=ev, right=elec, how='inner', on='legislative_district')
ev_elec = pd.merge(left=ev_elec, right=elec_county, how='inner', on='county', suffixes=('_ld','_cnty'))
ev_elec.head(1)
# Out:
#           vin  county     city state postal_code  model_year    make  \
# 0  JTMAB3FV3P  Kitsap  Seabeck    WA       98380        2023  TOYOTA
#
#         model                                 ev_type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#                           cafv_eligibility  ...  %_turnout_ld  \
# 0  Clean Alternative Fuel Vehicle Eligible  ...       0.68219
#
#    patty_murray_ld tiffany_smiley_ld party_won_ld registered_voters_cnty  \
# 0            35917             39273   Republican               187150.0
#
#   ballots_cast_cnty %_turnout_cnty  patty_murray_cnty  tiffany_smiley_cnty  \
# 0          124242.0       0.663863            70939.0              52134.0
#
#    party_won_cnty
# 0      Democratic
#
# [1 rows x 29 columns]

# %%
# save

with open('data/ev_elec.pickle', 'wb') as f:
    pickle.dump(ev_elec, f)

# with open('ev_elec.pickle', 'rb') as f:
#     ev_elec = pickle.load(f)

# %% [markdown]
# # Alternative Fuel Stations in Washington State
#
# - charging station info

# %%
# read alternative fuel stations in washington dataset
# source: https://afdc.energy.gov/data_download

charger = pd.read_csv('data/alt_fuel_stations (Oct 7 2024).csv')

charger.columns = ['_'.join(col.strip().lower().split()) for col in charger.columns]

charger.head(1)
# Out:
#   fuel_type_code                       station_name  street_address  \
# 0           ELEC  City of Lacey - City Hall Parking  420 College St
#
#                  intersection_directions   city state    zip  plus4  \
# 0  At 3rd Ave SE, next to police station  Lacey    WA  98503    NaN
#
#   station_phone status_code  ... rd_blends rd_blends_(french)  \
# 0  360-491-3214           E  ...       NaN                NaN
#
#   rd_blended_with_biodiesel rd_maximum_biodiesel_level  nps_unit_name  \
# 0                       NaN                        NaN            NaN
#
#    cng_station_sells_renewable_natural_gas  \
# 0                                      NaN
#
#    lng_station_sells_renewable_natural_gas  maximum_vehicle_class  \
# 0                                      NaN                     LD
#
#    ev_workplace_charging  funding_sources
# 0                  False              NaN
#
# [1 rows x 75 columns]

# %%
charger.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2705 entries, 0 to 2704
# Data columns (total 75 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   fuel_type_code                           2705 non-null   object
#  1   station_name                             2705 non-null   object
#  2   street_address                           2702 non-null   object
#  3   intersection_directions                  801 non-null    object
#  4   city                                     2705 non-null   object
#  5   state                                    2705 non-null   object
#  6   zip                                      2705 non-null   object
#  7   plus4                                    0 non-null      float64
#  8   station_phone                            2546 non-null   object
#  9   status_code                              2705 non-null   object
#  10  expected_date                            335 non-null    object
#  11  groups_with_access_code                  2705 non-null   object
#  12  access_days_time                         2471 non-null   object
#  13  cards_accepted                           180 non-null    object
#  14  bd_blends                                0 non-null      float64
#  15  ng_fill_type_code                        0 non-null      float64
#  16  ng_psi                                   0 non-null      float64
#  17  ev_level1_evse_num                       56 non-null     float64
#  18  ev_level2_evse_num                       2369 non-null   float64
#  19  ev_dc_fast_count                         386 non-null    float64
#  20  ev_other_info                            0 non-null      float64
#  21  ev_network                               2705 non-null   object
#  22  ev_network_web                           2374 non-null   object
#  23  geocode_status                           2705 non-null   object
#  24  latitude                                 2705 non-null   float64
#  25  longitude                                2705 non-null   float64
#  26  date_last_confirmed                      2700 non-null   object
#  27  id                                       2705 non-null   int64
#  28  updated_at                               2705 non-null   object
#  29  owner_type_code                          547 non-null    object
#  30  federal_agency_id                        103 non-null    float64
#  31  federal_agency_name                      103 non-null    object
#  32  open_date                                2704 non-null   object
#  33  hydrogen_status_link                     0 non-null      float64
#  34  ng_vehicle_class                         0 non-null      float64
#  35  lpg_primary                              0 non-null      float64
#  36  e85_blender_pump                         0 non-null      float64
#  37  ev_connector_types                       2705 non-null   object
#  38  country                                  2705 non-null   object
#  39  intersection_directions_(french)         0 non-null      float64
#  40  access_days_time_(french)                0 non-null      float64
#  41  bd_blends_(french)                       0 non-null      float64
#  42  groups_with_access_code_(french)         2705 non-null   object
#  43  hydrogen_is_retail                       0 non-null      float64
#  44  access_code                              2705 non-null   object
#  45  access_detail_code                       142 non-null    object
#  46  federal_agency_code                      103 non-null    object
#  47  facility_type                            540 non-null    object
#  48  cng_dispenser_num                        0 non-null      float64
#  49  cng_on-site_renewable_source             0 non-null      float64
#  50  cng_total_compression_capacity           0 non-null      float64
#  51  cng_storage_capacity                     0 non-null      float64
#  52  lng_on-site_renewable_source             0 non-null      float64
#  53  e85_other_ethanol_blends                 0 non-null      float64
#  54  ev_pricing                               590 non-null    object
#  55  ev_pricing_(french)                      0 non-null      float64
#  56  lpg_nozzle_types                         0 non-null      float64
#  57  hydrogen_pressures                       0 non-null      float64
#  58  hydrogen_standards                       0 non-null      float64
#  59  cng_fill_type_code                       0 non-null      float64
#  60  cng_psi                                  0 non-null      float64
#  61  cng_vehicle_class                        0 non-null      float64
#  62  lng_vehicle_class                        0 non-null      float64
#  63  ev_on-site_renewable_source              6 non-null      object
#  64  restricted_access                        348 non-null    object
#  65  rd_blends                                0 non-null      float64
#  66  rd_blends_(french)                       0 non-null      float64
#  67  rd_blended_with_biodiesel                0 non-null      float64
#  68  rd_maximum_biodiesel_level               0 non-null      float64
#  69  nps_unit_name                            22 non-null     object
#  70  cng_station_sells_renewable_natural_gas  0 non-null      float64
#  71  lng_station_sells_renewable_natural_gas  0 non-null      float64
#  72  maximum_vehicle_class                    323 non-null    object
#  73  ev_workplace_charging                    2705 non-null   bool
#  74  funding_sources                          0 non-null      float64
# dtypes: bool(1), float64(40), int64(1), object(33)
# memory usage: 1.5+ MB

# %%
charger.describe().T
# Out:
#                                           count           mean           std  \
# plus4                                       0.0            NaN           NaN
# bd_blends                                   0.0            NaN           NaN
# ng_fill_type_code                           0.0            NaN           NaN
# ng_psi                                      0.0            NaN           NaN
# ev_level1_evse_num                         56.0       2.946429      4.056060
# ev_level2_evse_num                       2369.0       2.317856      2.630517
# ev_dc_fast_count                          386.0       3.722798      3.989382
# ev_other_info                               0.0            NaN           NaN
# latitude                                 2705.0      47.444822      0.796243
# longitude                                2705.0    -121.865615      1.594457
# id                                       2705.0  215613.791128  84085.070862
# federal_agency_id                         103.0      11.145631      3.740105
# hydrogen_status_link                        0.0            NaN           NaN
# ng_vehicle_class                            0.0            NaN           NaN
# lpg_primary                                 0.0            NaN           NaN
# e85_blender_pump                            0.0            NaN           NaN
# intersection_directions_(french)            0.0            NaN           NaN
# access_days_time_(french)                   0.0            NaN           NaN
# bd_blends_(french)                          0.0            NaN           NaN
# hydrogen_is_retail                          0.0            NaN           NaN
# cng_dispenser_num                           0.0            NaN           NaN
# cng_on-site_renewable_source                0.0            NaN           NaN
# cng_total_compression_capacity              0.0            NaN           NaN
# cng_storage_capacity                        0.0            NaN           NaN
# lng_on-site_renewable_source                0.0            NaN           NaN
# e85_other_ethanol_blends                    0.0            NaN           NaN
# ev_pricing_(french)                         0.0            NaN           NaN
# lpg_nozzle_types                            0.0            NaN           NaN
# hydrogen_pressures                          0.0            NaN           NaN
# hydrogen_standards                          0.0            NaN           NaN
# cng_fill_type_code                          0.0            NaN           NaN
# cng_psi                                     0.0            NaN           NaN
# cng_vehicle_class                           0.0            NaN           NaN
# lng_vehicle_class                           0.0            NaN           NaN
# rd_blends                                   0.0            NaN           NaN
# rd_blends_(french)                          0.0            NaN           NaN
# rd_blended_with_biodiesel                   0.0            NaN           NaN
# rd_maximum_biodiesel_level                  0.0            NaN           NaN
# cng_station_sells_renewable_natural_gas     0.0            NaN           NaN
# lng_station_sells_renewable_natural_gas     0.0            NaN           NaN
# funding_sources                             0.0            NaN           NaN
#
#                                                 min            25%  \
# plus4                                           NaN            NaN
# bd_blends                                       NaN            NaN
# ng_fill_type_code                               NaN            NaN
# ng_psi                                          NaN            NaN
# ev_level1_evse_num                           1.0000       1.000000
# ev_level2_evse_num                           1.0000       1.000000
# ev_dc_fast_count                             1.0000       1.000000
# ev_other_info                                   NaN            NaN
# latitude                                    21.3563      47.313906
# longitude                                 -157.9382    -122.377102
# id                                       33351.0000  164568.000000
# federal_agency_id                            2.0000       8.000000
# hydrogen_status_link                            NaN            NaN
# ng_vehicle_class                                NaN            NaN
# lpg_primary                                     NaN            NaN
# e85_blender_pump                                NaN            NaN
# intersection_directions_(french)                NaN            NaN
# access_days_time_(french)                       NaN            NaN
# bd_blends_(french)                              NaN            NaN
# hydrogen_is_retail                              NaN            NaN
# cng_dispenser_num                               NaN            NaN
# cng_on-site_renewable_source                    NaN            NaN
# cng_total_compression_capacity                  NaN            NaN
# cng_storage_capacity                            NaN            NaN
# lng_on-site_renewable_source                    NaN            NaN
# e85_other_ethanol_blends                        NaN            NaN
# ev_pricing_(french)                             NaN            NaN
# lpg_nozzle_types                                NaN            NaN
# hydrogen_pressures                              NaN            NaN
# hydrogen_standards                              NaN            NaN
# cng_fill_type_code                              NaN            NaN
# cng_psi                                         NaN            NaN
# cng_vehicle_class                               NaN            NaN
# lng_vehicle_class                               NaN            NaN
# rd_blends                                       NaN            NaN
# rd_blends_(french)                              NaN            NaN
# rd_blended_with_biodiesel                       NaN            NaN
# rd_maximum_biodiesel_level                      NaN            NaN
# cng_station_sells_renewable_natural_gas         NaN            NaN
# lng_station_sells_renewable_natural_gas         NaN            NaN
# funding_sources                                 NaN            NaN
#
#                                                    50%            75%  \
# plus4                                              NaN            NaN
# bd_blends                                          NaN            NaN
# ng_fill_type_code                                  NaN            NaN
# ng_psi                                             NaN            NaN
# ev_level1_evse_num                            1.000000       3.000000
# ev_level2_evse_num                            2.000000       2.000000
# ev_dc_fast_count                              2.000000       4.000000
# ev_other_info                                      NaN            NaN
# latitude                                     47.615303      47.663670
# longitude                                  -122.323903    -122.176869
# id                                       201477.000000  306402.000000
# federal_agency_id                            10.000000      14.000000
# hydrogen_status_link                               NaN            NaN
# ng_vehicle_class                                   NaN            NaN
# lpg_primary                                        NaN            NaN
# e85_blender_pump                                   NaN            NaN
# intersection_directions_(french)                   NaN            NaN
# access_days_time_(french)                          NaN            NaN
# bd_blends_(french)                                 NaN            NaN
# hydrogen_is_retail                                 NaN            NaN
# cng_dispenser_num                                  NaN            NaN
# cng_on-site_renewable_source                       NaN            NaN
# cng_total_compression_capacity                     NaN            NaN
# cng_storage_capacity                               NaN            NaN
# lng_on-site_renewable_source                       NaN            NaN
# e85_other_ethanol_blends                           NaN            NaN
# ev_pricing_(french)                                NaN            NaN
# lpg_nozzle_types                                   NaN            NaN
# hydrogen_pressures                                 NaN            NaN
# hydrogen_standards                                 NaN            NaN
# cng_fill_type_code                                 NaN            NaN
# cng_psi                                            NaN            NaN
# cng_vehicle_class                                  NaN            NaN
# lng_vehicle_class                                  NaN            NaN
# rd_blends                                          NaN            NaN
# rd_blends_(french)                                 NaN            NaN
# rd_blended_with_biodiesel                          NaN            NaN
# rd_maximum_biodiesel_level                         NaN            NaN
# cng_station_sells_renewable_natural_gas            NaN            NaN
# lng_station_sells_renewable_natural_gas            NaN            NaN
# funding_sources                                    NaN            NaN
#
#                                                    max
# plus4                                              NaN
# bd_blends                                          NaN
# ng_fill_type_code                                  NaN
# ng_psi                                             NaN
# ev_level1_evse_num                           20.000000
# ev_level2_evse_num                           68.000000
# ev_dc_fast_count                             24.000000
# ev_other_info                                      NaN
# latitude                                     48.995255
# longitude                                  -117.043496
# id                                       357526.000000
# federal_agency_id                            20.000000
# hydrogen_status_link                               NaN
# ng_vehicle_class                                   NaN
# lpg_primary                                        NaN
# e85_blender_pump                                   NaN
# intersection_directions_(french)                   NaN
# access_days_time_(french)                          NaN
# bd_blends_(french)                                 NaN
# hydrogen_is_retail                                 NaN
# cng_dispenser_num                                  NaN
# cng_on-site_renewable_source                       NaN
# cng_total_compression_capacity                     NaN
# cng_storage_capacity                               NaN
# lng_on-site_renewable_source                       NaN
# e85_other_ethanol_blends                           NaN
# ev_pricing_(french)                                NaN
# lpg_nozzle_types                                   NaN
# hydrogen_pressures                                 NaN
# hydrogen_standards                                 NaN
# cng_fill_type_code                                 NaN
# cng_psi                                            NaN
# cng_vehicle_class                                  NaN
# lng_vehicle_class                                  NaN
# rd_blends                                          NaN
# rd_blends_(french)                                 NaN
# rd_blended_with_biodiesel                          NaN
# rd_maximum_biodiesel_level                         NaN
# cng_station_sells_renewable_natural_gas            NaN
# lng_station_sells_renewable_natural_gas            NaN
# funding_sources                                    NaN

# %% [markdown]
# ## Data Cleaning

# %%
# drop all-null cols
charger = charger.dropna(axis=1, how='all')
print_cols(charger, 3)
# Out:
# (2705, 41)
#   fuel_type_code                                       station_name  \
# 0           ELEC                  City of Lacey - City Hall Parking
# 1           ELEC  Seattle-Tacoma International Airport - General...
# 2           ELEC                                        Avista Corp
#
#         street_address                     intersection_directions     city  \
# 0       420 College St       At 3rd Ave SE, next to police station    Lacey
# 1  17801 Pacific Hwy S  5th floor parking garage; rows D, G, and I  Seattle
# 2   1411 E Mission Ave                                         NaN  Spokane
#
#   state    zip station_phone status_code expected_date  \
# 0    WA  98503  360-491-3214           E           NaN
# 1    WA  98188  206-787-5388           E           NaN
# 2    WA  99252  509-489-0500           E           NaN
#
#   groups_with_access_code                                   access_days_time  \
# 0                  Public                                     24 hours daily
# 1                  Public  24 hours daily; pay lot; Drivers must bring th...
# 2                  Public  24 hours daily; Drivers must bring their own J...
#
#   cards_accepted  ev_level1_evse_num  ev_level2_evse_num  ev_dc_fast_count  \
# 0            NaN                 NaN              4.0000               NaN
# 1            NaN                 NaN             68.0000               NaN
# 2            NaN              1.0000              2.0000               NaN
#
#       ev_network ev_network_web geocode_status  latitude  longitude  \
# 0  Non-Networked            NaN          200-9   47.0440  -122.8224
# 1  Non-Networked            NaN          200-8   47.4434  -122.2962
# 2  Non-Networked            NaN            GPS   47.6733  -117.3889
#
#   date_last_confirmed     id               updated_at owner_type_code  \
# 0          2023-01-10  33351  2023-02-14 15:54:11 UTC              LG
# 1          2023-12-13  33717  2024-01-31 22:07:01 UTC               P
# 2          2023-06-12  35620  2024-01-31 22:07:01 UTC               P
#
#    federal_agency_id federal_agency_name   open_date ev_connector_types  \
# 0                NaN                 NaN  2018-01-15              J1772
# 1                NaN                 NaN  2010-03-01              J1772
# 2                NaN                 NaN  2010-04-15      J1772 NEMA520
#
#   country groups_with_access_code_(french) access_code access_detail_code  \
# 0      US                           Public      public                NaN
# 1      US                           Public      public                NaN
# 2      US                           Public      public                NaN
#
#   federal_agency_code facility_type                             ev_pricing  \
# 0                 NaN      MUNI_GOV  Free; 3 hour maximum charging session
# 1                 NaN       AIRPORT                                   Free
# 2                 NaN   OFFICE_BLDG                                   Free
#
#   ev_on-site_renewable_source restricted_access nps_unit_name  \
# 0                         NaN             False           NaN
# 1                         NaN             False           NaN
# 2                         NaN             False           NaN
#
#   maximum_vehicle_class  ev_workplace_charging
# 0                    LD                  False
# 1                    LD                  False
# 2                    LD                  False

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Each data has no info about legislative district nor county
#
# Using the coordinates (latitude and longitude), I will geocode them and get the corresponding legislative district information for each charging stateion

# %%
# geocode legislative district using latitude/longitude coordinate
# reference: https://geocoding.geo.census.gov/geocoder/Geocoding_Services_API.pdf
# source: 
# lon = -122.822404
# lat = 47.044011
# https://geocoding.geo.census.gov/geocoder/geographies/coordinates?x=-122.822404&y=47.044011&benchmark=4&vintage=4

import re
import time
import requests
from tqdm import tqdm
from joblib import Parallel, delayed

# extract legislative district numbers using latitude/longitude coordinate
def get_legislative_district(lon, lat):
    api_url = "https://geocoding.geo.census.gov/geocoder/geographies/coordinates"
    params = {
        "benchmark": "Public_AR_Current",
        "vintage": "Current_Current",
        "x": lon, # longitude
        "y": lat, # latitude 
        "format": "json"
    }
    response = requests.get(api_url, params=params)
    data = response.json()
    try:
        upper_district = data["result"]["geographies"]['2024 State Legislative Districts - Upper'][0]["NAME"]
        lower_district = data["result"]["geographies"]['2024 State Legislative Districts - Lower'][0]["NAME"]

        upper_district = re.findall(r'\d+', upper_district)
        lower_district = re.findall(r'\d+', lower_district)

        # if district number exists, extract it; if not, None
        upper_district = upper_district[0] if upper_district else None
        lower_district = lower_district[0] if lower_district else None
        
        return upper_district, lower_district
    except Exception as e:
        print(f"Error: {e}")
        return None

# parallel process
def parallel_process(charger, n_jobs=-1):
    coordinates = ['longitude','latitude']
    results = Parallel(backend='loky', n_jobs=n_jobs)(delayed(get_legislative_district)(row[0], row[1]) for row in tqdm(charger[coordinates].itertuples(index=False), total=len(charger), leave=True, position=0))
    return results

districts_list = parallel_process(charger)
charger[['legislative_district_upper','legislative_district_lower']] = districts_list
print_cols(charger, 2)
# Out:
# 100%|███████████████████████████████████████| 2705/2705 [01:56<00:00, 23.29it/s]
# (2705, 43)
#   fuel_type_code                                       station_name  \
# 0           ELEC                  City of Lacey - City Hall Parking
# 1           ELEC  Seattle-Tacoma International Airport - General...
#
#         street_address                     intersection_directions     city  \
# 0       420 College St       At 3rd Ave SE, next to police station    Lacey
# 1  17801 Pacific Hwy S  5th floor parking garage; rows D, G, and I  Seattle
#
#   state    zip station_phone status_code expected_date  \
# 0    WA  98503  360-491-3214           E           NaN
# 1    WA  98188  206-787-5388           E           NaN
#
#   groups_with_access_code                                   access_days_time  \
# 0                  Public                                     24 hours daily
# 1                  Public  24 hours daily; pay lot; Drivers must bring th...
#
#   cards_accepted  ev_level1_evse_num  ev_level2_evse_num  ev_dc_fast_count  \
# 0            NaN                 NaN              4.0000               NaN
# 1            NaN                 NaN             68.0000               NaN
#
#       ev_network ev_network_web geocode_status  latitude  longitude  \
# 0  Non-Networked            NaN          200-9   47.0440  -122.8224
# 1  Non-Networked            NaN          200-8   47.4434  -122.2962
#
#   date_last_confirmed     id               updated_at owner_type_code  \
# 0          2023-01-10  33351  2023-02-14 15:54:11 UTC              LG
# 1          2023-12-13  33717  2024-01-31 22:07:01 UTC               P
#
#    federal_agency_id federal_agency_name   open_date ev_connector_types  \
# 0                NaN                 NaN  2018-01-15              J1772
# 1                NaN                 NaN  2010-03-01              J1772
#
#   country groups_with_access_code_(french) access_code access_detail_code  \
# 0      US                           Public      public                NaN
# 1      US                           Public      public                NaN
#
#   federal_agency_code facility_type                             ev_pricing  \
# 0                 NaN      MUNI_GOV  Free; 3 hour maximum charging session
# 1                 NaN       AIRPORT                                   Free
#
#   ev_on-site_renewable_source restricted_access nps_unit_name  \
# 0                         NaN             False           NaN
# 1                         NaN             False           NaN
#
#   maximum_vehicle_class  ev_workplace_charging legislative_district_upper  \
# 0                    LD                  False                         22
# 1                    LD                  False                         33
#
#   legislative_district_lower
# 0                         22
# 1                         33

# %%
# check missing value
district_cols = ['legislative_district_upper','legislative_district_lower']
charger[district_cols].isna().sum()
# Out:
# legislative_district_upper    0
# legislative_district_lower    0
# dtype: int64

# %%
# charging stations with different ld upper and ld lower 
cond = charger['legislative_district_upper'] != charger['legislative_district_lower']
charger[cond][district_cols]
# Out:
#     legislative_district_upper legislative_district_lower
# 434                         15                         31

# %% [markdown]
# - upper is for senate, so using uppoer ld

# %%
# save
with open('data/charger.pickle', 'wb') as f:
    pickle.dump(charger, f)

# with open('charger.pickle', 'rb') as f:
#     charger = pickle.load(f)
